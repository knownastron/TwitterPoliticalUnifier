# %%
list1 = 'AK     Lisa Murkowski @lisamurkowski AK     Dan Sullivan @SenDanSullivan ALDoug Jones @SenDougJones ALRichard C. Shelby @SenShelby AR     John Boozman @JohnBoozman AR     Tom Cotton @SenTomCotton AZMartha McSally @SenMcSallyAZ AZKyrsten Sinema @SenatorSinema CA     Dianne Feinstein @SenFeinstein CA     Kamala D. Harris @SenKamalaHarris CO    Michael F. Bennet @SenatorBennet CO    Cory Gardner @SenCoryGardner CT     Richard Blumenthal @SenBlumenthal CT     Christopher Murphy @SenMurphyOfficeDEThomas R. Carper@SenatorCarper DE     Christopher A. Coons @ChrisCoons FLMarco Rubio @SenRubioPressFLRick Scott @SenRickScott GA    Johnny Isakson @SenatorIsakson GA    David Perdue @sendavidperdue HI Mazie K. Hirono @maziehirono HI Brian Schatz @SenBrianSchatz IA  Joni Ernst @SenJoniErnst IA  Chuck Grassley @ChuckGrassley ID  Mike Crapo @MikeCrapo ID  James E. Risch @SenatorRisch IL  Tammy Duckworth @SenDuckworth IL  Richard J. Durbin @SenatorDurbin IN  Mike Braun @SenatorBraun IN  Todd Young @SenToddYoung KS     Jerry Moran @JerryMoran KS     Pat Roberts @SenPatRoberts KY     Mitch McConnell @SenateMajLdr KY     Rand Paul @RandPaul LABill Cassidy @SenBillCassidy LAJohn Kennedy @SenJohnKennedy MA    Edward J. Markey @SenMarkey MA    Elizabeth Warren @SenWarren MD    Benjamin L. Cardin @SenatorCardin MD    Chris Van Hollen @ChrisVanHollen ME    Susan M. Collins @SenatorCollins ME    Angus S. King, Jr. @SenAngusKing MI    Gary C. Peters @SenGaryPeters MI    Debbie Stabenow @SenStabenow MN    Amy Klobuchar @SenAmyKlobuchar MN    Tina Smith @SenTinaSmith MO    Roy Blunt @RoyBlunt MO    Josh Hawley @SenHawleyPress MS    Cindy Hyde-Smith @SenHydeSmith MS    Roger F. Wicker @SenatorWicker'
list2 = 'MT    Steve Daines @SteveDaines MT    Jon Tester @SenatorTester NC    Richard Burr @SenatorBurr NC    Thom Tillis @SenThomTillis ND    Kevin Cramer @SenKevinCramer ND    John Hoeven @SenJohnHoeven NE    Deb Fischer @SenatorFischer NE    Ben Sasse @SenSasse NH    Margaret Wood Hassan    @SenatorHassan NH    Jeanne Shaheen @SenatorShaheen NJ     Cory A. Booker @SenBooker NJ     Robert Menendez @SenatorMenendez NM    Martin Heinrich @MartinHeinrich NM    Tom Udall @SenatorTomUdall NV    Catherine Cortez Masto    @SenCortezMasto NV    Jacky Rosen @SenJackyRosen NY    Kirsten E. Gillibrand @gillibrandny NY    Charles E. Schumer @SenSchumer OH    Sherrod Brown @SenSherrodBrown OH    Rob Portman @senrobportman OK    James M. Inhofe @JimInhofe OK    James Lankford @SenatorLankford OR    Jeff Merkley @SenJeffMerkley OR    Ron Wyden @RonWyden PA     Robert P. Casey, Jr. @SenBobCasey PA     Patrick J. Toomey @SenToomey RI Jack Reed @SenJackReed RI Sheldon Whitehouse @SenWhitehouse SC    Lindsey Graham @LindseyGrahamSC SC    Tim Scott @SenatorTimScott SD    Mike Rounds @SenatorRounds SD    John Thune @SenJohnThune TN     Lamar Alexander @SenAlexander TN     Marsha Blackburn @MarshaBlackburn TX     John Cornyn @JohnCornyn TX     Ted Cruz @SenTedCruz UT     Mike Lee @SenMikeLee UT     Mitt Romney @SenatorRomney VA     Time Kaine N/AVA     Mark R. Warner @MarkWarner VT     Patrick J. Leahy @SenatorLeahy VT     Bernard Sanders @SenSanders WA    Maria Cantwell @SenatorCantwell WA    Patty Murray @PattyMurray WI     Tammy Baldwin @SenatorBaldwin WI     Ron Johnson @SenRonJohnson WV    Shelley Moore Capito @SenCapito WV    Joe Manchin, III @Sen_JoeManchin WY    John Barrasso @SenJohnBarrasso WY    Michael B. Enzi @SenatorEnzi '

# %%
list1_split = list1.split()
list2_split = list2.split()

# %%
handles1 = [x[1:] for x in list1_split if x[0] == '@']
handles2 = [x[1:] for x in list2_split if x[0] == '@']

# %%
accounts = handles1 + handles2

# %%
print(accounts)
# Out:
# ['lisamurkowski', 'SenDanSullivan', 'SenDougJones', 'SenShelby', 'JohnBoozman', 'SenTomCotton', 'SenMcSallyAZ', 'SenatorSinema', 'SenFeinstein', 'SenKamalaHarris', 'SenatorBennet', 'SenCoryGardner', 'SenBlumenthal', 'SenMurphyOfficeDEThomas', 'ChrisCoons', 'SenRubioPressFLRick', 'SenRickScott', 'SenatorIsakson', 'sendavidperdue', 'maziehirono', 'SenBrianSchatz', 'SenJoniErnst', 'ChuckGrassley', 'MikeCrapo', 'SenatorRisch', 'SenDuckworth', 'SenatorDurbin', 'SenatorBraun', 'SenToddYoung', 'JerryMoran', 'SenPatRoberts', 'SenateMajLdr', 'RandPaul', 'SenBillCassidy', 'SenJohnKennedy', 'SenMarkey', 'SenWarren', 'SenatorCardin', 'ChrisVanHollen', 'SenatorCollins', 'SenAngusKing', 'SenGaryPeters', 'SenStabenow', 'SenAmyKlobuchar', 'SenTinaSmith', 'RoyBlunt', 'SenHawleyPress', 'SenHydeSmith', 'SenatorWicker', 'SteveDaines', 'SenatorTester', 'SenatorBurr', 'SenThomTillis', 'SenKevinCramer', 'SenJohnHoeven', 'SenatorFischer', 'SenSasse', 'SenatorHassan', 'SenatorShaheen', 'SenBooker', 'SenatorM
# ...

# %%
dems = []
gops = []

# %%
for account in accounts:
    answer = input(account)
    if answer[0].lower() == 'd':
        dems.append(account)
        print('DEMOCRAT')
    elif answer[0].lower() == 'g':
        gops.append(account)
        print('GOP')
# Out:
# lisamurkowskig
# GOP
# SenDanSullivang
# GOP
# SenDougJonesd
# DEMOCRAT
# SenShelbyg
# GOP
# JohnBoozmang
# GOP
# SenTomCottong
# GOP
# SenMcSallyAZg
# GOP
# SenatorSinemad
# DEMOCRAT
# SenFeinsteind
# DEMOCRAT
# SenKamalaHarrisd
# DEMOCRAT
# SenatorBennetd
# DEMOCRAT
# SenCoryGardnerg
# GOP
# SenBlumenthald
# DEMOCRAT
# SenMurphyOfficeDEThomasd
# DEMOCRAT
# ChrisCoonsd
# DEMOCRAT
# SenRubioPressFLRickr
# SenRickScottg
# GOP
# SenatorIsaksong
# GOP
# sendavidperdueg
# GOP
# maziehironod
# DEMOCRAT
# SenBrianSchatzd
# DEMOCRAT
# SenJoniErnstg
# GOP
# ChuckGrassleyg
# GOP
# MikeCrapog
# GOP
# SenatorRischg
# GOP
# SenDuckworthd
# DEMOCRAT
# SenatorDurbind
# DEMOCRAT
# SenatorBraung
# GOP
# SenToddYoungg
# GOP
# JerryMorang
# GOP
# SenPatRobertsg
# GOP
# SenateMajLdrd
# DEMOCRAT
# RandPaulg
# GOP
# SenBillCassidyg
# GOP
# SenJohnKennedyg
# GOP
# SenMarkeyd
# DEMOCRAT
# SenWarrend
# DEMOCRAT
# SenatorCardind
# DEMOCRAT
# ChrisVanHollend
# DEMOCRAT
# SenatorCollinsg
# GOP
# SenAngusKingn
# ...

# %%
print(len(gops))
# Out:
# 76

# %%
print(len(dems))
# Out:
# 69

# %%
gop_set = set(gops)
dems_set = set(dems)

# %%
print(len(gop_set))
# Out:
# 51

# %%
print(len(dems_set))
# Out:
# 45

# %%
gop_set
# Out:
# {'ChuckGrassley',
#  'JerryMoran',
#  'JimInhofe',
#  'JohnBoozman',
#  'JohnCornyn',
#  'LindseyGrahamSC',
#  'MarshaBlackburn',
#  'MikeCrapo',
#  'RandPaul',
#  'RoyBlunt',
#  'SenAlexander',
#  'SenBillCassidy',
#  'SenCapito',
#  'SenCoryGardner',
#  'SenDanSullivan',
#  'SenHawleyPress',
#  'SenHydeSmith',
#  'SenJohnBarrasso',
#  'SenJohnHoeven',
#  'SenJohnKennedy',
#  'SenJohnThune',
#  'SenJoniErnst',
#  'SenKevinCramer',
#  'SenMcSallyAZ',
#  'SenMikeLee',
#  'SenPatRoberts',
#  'SenRickScott',
#  'SenRonJohnson',
#  'SenSasse',
#  'SenShelby',
#  'SenTedCruz',
#  'SenThomTillis',
#  'SenToddYoung',
#  'SenTomCotton',
#  'SenToomey',
#  'SenatorBraun',
#  'SenatorBurr',
#  'SenatorCollins',
#  'SenatorEnzi',
#  'SenatorFischer',
#  'SenatorIsakson',
#  'SenatorLankford',
#  'SenatorRisch',
#  'SenatorRomney',
#  'SenatorRounds',
#  'SenatorTimScott',
#  'SenatorWicker',
#  'SteveDaines',
#  'lisamurkowski',
#  'sendavidperdue',
#  'senrobportman'}

# %%
dems_set
# Out:
# {'ChrisCoons',
#  'ChrisVanHollen',
#  'MarkWarner',
#  'MartinHeinrich',
#  'PattyMurray',
#  'RonWyden',
#  'SenAmyKlobuchar',
#  'SenBlumenthal',
#  'SenBobCasey',
#  'SenBooker',
#  'SenBrianSchatz',
#  'SenCortezMasto',
#  'SenDougJones',
#  'SenDuckworth',
#  'SenFeinstein',
#  'SenGaryPeters',
#  'SenJackReed',
#  'SenJackyRosen',
#  'SenJeffMerkley',
#  'SenKamalaHarris',
#  'SenMarkey',
#  'SenMurphyOfficeDEThomas',
#  'SenSanders',
#  'SenSchumer',
#  'SenSherrodBrown',
#  'SenStabenow',
#  'SenTinaSmith',
#  'SenWarren',
#  'SenWhitehouse',
#  'Sen_JoeManchin',
#  'SenateMajLdr',
#  'SenatorBaldwin',
#  'SenatorBennet',
#  'SenatorCantwell',
#  'SenatorCardin',
#  'SenatorDurbin',
#  'SenatorHassan',
#  'SenatorLeahy',
#  'SenatorMenendez',
#  'SenatorShaheen',
#  'SenatorSinema',
#  'SenatorTester',
#  'SenatorTomUdall',
#  'gillibrandny',
#  'maziehirono'}

# %%
for person in dems_set:
    print(person)
# Out:
# SenStabenow
# SenSherrodBrown
# PattyMurray
# SenatorHassan
# SenBlumenthal
# Sen_JoeManchin
# SenDuckworth
# maziehirono
# SenGaryPeters
# SenSchumer
# RonWyden
# SenCortezMasto
# SenatorLeahy
# SenFeinstein
# SenatorCantwell
# SenJeffMerkley
# SenatorCardin
# SenJackReed
# SenMarkey
# SenatorTester
# SenDougJones
# SenJackyRosen
# SenSanders
# SenWhitehouse
# SenBooker
# SenatorSinema
# SenatorMenendez
# SenBrianSchatz
# SenMurphyOfficeDEThomas
# gillibrandny
# SenatorBennet
# SenTinaSmith
# SenAmyKlobuchar
# SenatorBaldwin
# SenBobCasey
# SenKamalaHarris
# MartinHeinrich
# SenatorTomUdall
# SenatorDurbin
# MarkWarner
# SenWarren
# SenateMajLdr
# ChrisVanHollen
# ChrisCoons
# SenatorShaheen
